# %%
import pickle
from IPython.display import Markdown as md
from time import gmtime, strftime
from platform import platform
import pandas as pd

# %%
def success(message: str):
    
    return('%s<span style="color:green;"> ... ✓ </span>' % message)

def failure(message: str):
    
    return('%s<span style="color:red;"> ... X</span>' % message)

def check_conditional(key: str, value: str):
    
    if '_SUCCESS' in key:
    
        return(success(value))

    else:

        return(failure(value))
    
def print_checks(log, check_type = 'OUTPUT_CHECK'):

    s = []
    for k, row in log.loc[[check_type in x for x in log['key']], :].iterrows():

        s.append(check_conditional(row['key'], row['value']))

    return(s)

def print_records_summary(log):
    
    s = []
    for k, row in log.loc[['_RECORDS' in x for x in log['key']], :].iterrows():

        s.append(row['key'] + ': ' + row['value'])
    
    return(s)

# %%
report = pickle.load( open( "../tmp/report.pickle", "rb" ) )

# %% [markdown]
# # WHO PHSM Cleaning Technical Report

# %% [markdown]
# Generated by **WHO_PHSM_Cleaning**. More information available on [GitHub](https://github.com/lshtm-gis/WHO_PHSM_Cleaning).

# %% [markdown]
# For more details on the processing routine, please see the [project documentation](https://lshtm-gis.github.io/WHO_PHSM_Cleaning/html/).

# %% [markdown]
# *See a problem with the data or processing routine? Please [open an issue](https://github.com/lshtm-gis/WHO_PHSM_Cleaning/issues/new).*

# %% [markdown]
# ## Session Details
# ***

# %%
md('<b>Report generated:</b> ' + strftime("%Y-%m-%d %H:%M:%S", gmtime()))
# Out:
# <b>Report generated:</b> 2020-10-29 14:40:10

# %%
md('<b>Platform:</b> ' + platform())
# Out:
# <b>Platform:</b> Darwin-19.6.0-x86_64-i386-64bit

# %% [markdown]
# ## Preprocessing
# ***
#
# ### Description
#
# Ingests provider data, checks input data format.

# %%
preprocess = pd.DataFrame(report['preprocess']).dropna(subset = ['key'])

# %% [markdown]
# ### Summary

# %%
s = print_records_summary(preprocess)
md('<br>'.join(s))
# Out:
# JH_HIT_RECORDS: 11806<br>CDC_ITF_RECORDS: 7714<br>ACAPS_RECORDS: 18694<br>INPUT_RECORDS: 38214

# %% [markdown]
# ### Checks

# %%
s = print_checks(preprocess, 'INPUT_CHECK')
md('<br>'.join(s))
# Out:
# JH_HIT input columns OK.<span style="color:green;"> ... ✓ </span><br>JH_HIT entry_time date format is %Y-%m-d.<span style="color:green;"> ... ✓ </span><br>CDC_ITF input columns OK.<span style="color:green;"> ... ✓ </span><br>CDC_ITF Date Entered date format is %Y-%m-d.<span style="color:green;"> ... ✓ </span><br>ACAPS input columns OK.<span style="color:green;"> ... ✓ </span><br>ACAPS DATE_IMPLEMENTED date format is %Y-%m-d.<span style="color:green;"> ... ✓ </span>

# %% [markdown]
# ## Processing
# ***
#
# ### Description
#
# Transforms individual records. Converts column names, parses date formats, applies custom changes for each dataset.

# %%
process = pd.DataFrame(report['process']).dropna(subset = ['key'])

# %% [markdown]
# ### Summary

# %%
s = print_records_summary(process)
md('<br>'.join(s))
# Out:
# ACAPS_RECORDS: 18694<br>CDC_ITF_RECORDS: 7714<br>JH_HIT_RECORDS: 1883

# %% [markdown]
# ### Checks

# %%
s = print_checks(process)
md('<br>'.join(s))
# Out:
# Data has expected column names.<span style="color:green;"> ... ✓ </span><br>No Duplicate who_id.<span style="color:green;"> ... ✓ </span><br>No Duplicate prev_measure_number.<span style="color:green;"> ... ✓ </span><br>No Duplicate following_measure_number.<span style="color:green;"> ... ✓ </span><br>No unexpected values in admin_level.<span style="color:green;"> ... ✓ </span><br>No unexpected values in enforcement.<span style="color:green;"> ... ✓ </span><br>No unexpected values in keep.<span style="color:green;"> ... ✓ </span><br>No unexpected values in link_eng.<span style="color:green;"> ... ✓ </span><br>Unexpected values in measure_stage: Introduction / extension of measures, Phase-out measure, Ease, Pause, Strengthen, Impose, Lift.<span style="color:red;"> ... X</span><br>Unexpected values in non_compliance_penalty: nan, Up to Detention, Not applicable, Legal Action, Arrest/Detention, Legal action, yes, Not available , Not available, Refusal to enter the country, No, Fines, Other (add in comments), Up to detention, Yes , Not Available, Not Applicable, No', Yes, Refusal to Enter the Country, Other.<span style="color:red;"> ... X</span><br>No unexpected values in processed.<span style="color:green;"> ... ✓ </span><br>No unexpected values in reason_ended.<span style="color:green;"> ... ✓ </span><br>No unknown values in iso_3166_1_numeric.<span style="color:green;"> ... ✓ </span><br>No unknown values in who_region.<span style="color:green;"> ... ✓ </span><br>No unknown values in country_territory_area.<span style="color:green;"> ... ✓ </span><br>No unknown values in who_code.<span style="color:green;"> ... ✓ </span><br>No unknown values in who_measure.<span style="color:green;"> ... ✓ </span><br>No unknown values in who_subcategory.<span style="color:green;"> ... ✓ </span><br>No unknown values in who_category.<span style="color:green;"> ... ✓ </span><br>1 values in duplicate_record_id are missing from who_id.<span style="color:red;"> ... X</span><br>1 values in prev_measure_number are missing from who_id.<span style="color:red;"> ... X</span><br>1 values in following_measure_number are missing from who_id.<span style="color:red;"> ... X</span>

# %% [markdown]
# ## Postprocessing
# ***
#
# ### Description
#
# Applies dataset-level changes. Applies custom changes that affect multiple records from a data provider.

# %%
postprocess = pd.DataFrame(report['postprocess']).dropna(subset = ['key'])

# %% [markdown]
# ### Summary

# %%
s = print_records_summary(postprocess)
md('<br>'.join(s))

# %% [markdown]
# ### Checks

# %%
s = print_checks(postprocess)
md('<br>'.join(s))

# %% [markdown]
# ## Manual Cleaning
# ***
#
# ### Description
# Process manually cleaned data returned from volunteers.

# %%
manually_cleaned = pd.DataFrame(report['manually_cleaned']).dropna(subset = ['key'])

# %% [markdown]
# ### Summary

# %%
s = print_records_summary(manually_cleaned)
md('<br>'.join(s))
# Out:
# ACAPS_RECORDS: 18844<br>CDC_ITF_RECORDS: 7858<br>JH_HIT_RECORDS: 4805<br>OxCGRT_RECORDS: 25377<br>sequenced_RECORDS: 56884

# %% [markdown]
# ### Checks

# %%
s = print_checks(manually_cleaned)
md('<br>'.join(s))

# %% [markdown]
# ## Master
# ***
#
# ### Description
# Combine manually cleaned data with update data.

# %%
master = pd.DataFrame(report['master']).dropna(subset = ['key'])

# %% [markdown]
# ### Summary

# %%
s = print_records_summary(master)
md('<br>'.join(s))
# Out:
# ACAPS_RECORDS: 18844<br>CDC_ITF_RECORDS: 7858<br>JH_HIT_RECORDS: 4805<br>OxCGRT_RECORDS: 25377<br>sequenced_RECORDS: 56884

# %% [markdown]
# ### Checks

# %%
s = print_checks(master)
md('<br>'.join(s))
